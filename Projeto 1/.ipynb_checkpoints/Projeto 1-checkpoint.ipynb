# %% [markdown]
# ___
# # Ciência dos Dados - PROJETO 1

# %% [markdown]
# ## Juliano Nehme Nassar
# ___

# %% [markdown]
#   ## Sáude alimentar por região

# %% [markdown]
# ___
# ## Introdução
#
# Descreva aqui o que pretende analisar!
#
# Capriche no português!!
# Se quiser pode utilizar pesquisas semelhantes publicadas em sites confiáveis!!

# %% [markdown]
# ___
# ## Análise e Resultados

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\Julian\Desktop\Matérias\Ciência dos Dados\CienciaDosDados

# %%
#Se usar o arquivo descompactado
dados = pd.read_csv('DOM2009.csv',sep=',')

#Se usar o arquivo compactado como está no dropbox púbico
#pd.read_csv('DOM2015csv.zip', compression='zip', header=0, sep=',', quotechar='"')

# %%
NewData = pd.DataFrame({'Unidade Federal': dados.UF,
                        'Remdimento salarios min': dados.V4622,
                        'Segurança Alimentar': dados.V4623,
                       'Rendimento valor':dados.V4621})
pd.set_option('display.float_format', lambda x: '%.0f' % x)
NewData = NewData[(NewData['Rendimento valor']<= 20000) ].dropna(axis=0)
NewData
# Out:
#         Remdimento salarios min  Rendimento valor  Segurança Alimentar  \
# 2                             2               118                    3
# 3                             5              1053                    6
# 4                             4               930                    6
# 6                             2               232                    1
# 7                             3               248                    1
# 8                             1                59                    3
# 9                             7              6512                    7
# 10                            1                87                    3
# 12                            3               248                    1
# 13                            0                 0                    1
# 14                            4               500                    7
# 15                            3               321                    1
# 16                            1                94                    1
# 18                            2               154                    1
# 19                            1               111                    4
# 21                            3               465                    1
# 22                            6              1400                    6
# 23                            1               105                    1
# 24                            2               136                    1
# 25                            4               576                    8
# 26                            5              1017                    1
# 27                            2               175                    9
# 29                            1                30                    2
# 30                            2               175                    2
# 31                            3               465                    2
# 33                            4               750                    2
# 37                            3               283                    1
# 39                            4               672                    6
# 40                            4               750                    1
# 41                            4               600                    6
# ...                         ...               ...                  ...
# 153783                        7              5500                    6
# 153784                        6              1666                    1
# 153785                        7              5666                    1
# 153786                        7             11000                    6
# 153787                        6              1632                    6
# 153789                        6              1650                    6
# 153790                        7              5000                    1
# 153791                        7              5000                    6
# 153792                        7              3000                    1
# 153794                        4               750                    1
# 153795                        7              2800                    6
# 153796                        5              1225                    1
# 153797                        7              4000                    6
# 153798                        7              6000                    6
# 153799                        6              1650                    6
# 153801                        7              6500                    1
# 153802                        7              4500                    6
# 153808                        7              8000                    6
# 153810                        6              1510                    2
# 153811                        7              3370                    1
# 153815                        7              7760                    6
# 153817                        7              2400                    1
# 153818                        7              4700                    6
# 153819                        7              4775                    1
# 153823                        7              3242                    1
# 153830                        6              2000                    6
# 153832                        7              2500                    6
# 153834                        7              8333                    1
# 153835                        7              7166                    1
# 153836                        7              2500                    1
#
#         Unidade Federal
# 2                    11
# 3                    11
# 4                    11
# 6                    11
# 7                    11
# 8                    11
# 9                    11
# 10                   11
# 12                   11
# 13                   11
# 14                   11
# 15                   11
# 16                   11
# 18                   11
# 19                   11
# 21                   11
# 22                   11
# 23                   11
# 24                   11
# 25                   11
# 26                   11
# 27                   11
# 29                   11
# 30                   11
# 31                   11
# 33                   11
# 37                   11
# 39                   11
# 40                   11
# 41                   11
# ...                 ...
# 153783               53
# 153784               53
# 153785               53
# 153786               53
# 153787               53
# 153789               53
# 153790               53
# 153791               53
# 153792               53
# 153794               53
# 153795               53
# 153796               53
# 153797               53
# 153798               53
# 153799               53
# 153801               53
# 153802               53
# 153808               53
# 153810               53
# 153811               53
# 153815               53
# 153817               53
# 153818               53
# 153819               53
# 153823               53
# 153830               53
# 153832               53
# 153834               53
# 153835               53
# 153836               53
#
# [117775 rows x 4 columns]

# %%
def SegAlim(NewData):
    if NewData['Segurança Alimentar']== 1 or NewData['Segurança Alimentar']== 2 or NewData['Segurança Alimentar']== 6 or NewData['Segurança Alimentar']== 7:
        return 'sim'
    else:
        return 'não'
    
def Region(NewData):
    if NewData['Unidade Federal'] >= 11 and NewData['Unidade Federal'] <= 17:
        return 'Norte'
    if NewData['Unidade Federal'] >= 21 and NewData['Unidade Federal'] <= 29:
        return 'Nordeste'
    if NewData['Unidade Federal'] >= 31 and NewData['Unidade Federal'] <= 35:
        return 'Sudeste'
    if NewData['Unidade Federal'] >= 41 and NewData['Unidade Federal'] <= 43:
        return 'Sul'
    else:
        return 'Centro-Oeste'
NewData['Segurança alimentar'] = NewData.apply(SegAlim, axis=1)
NewData['Regiao'] = NewData.apply(Region, axis=1)
NewData
# Out:
#         Remdimento salarios min  Rendimento valor  Segurança Alimentar  \
# 2                             2               118                    3
# 3                             5              1053                    6
# 4                             4               930                    6
# 6                             2               232                    1
# 7                             3               248                    1
# 8                             1                59                    3
# 9                             7              6512                    7
# 10                            1                87                    3
# 12                            3               248                    1
# 13                            0                 0                    1
# 14                            4               500                    7
# 15                            3               321                    1
# 16                            1                94                    1
# 18                            2               154                    1
# 19                            1               111                    4
# 21                            3               465                    1
# 22                            6              1400                    6
# 23                            1               105                    1
# 24                            2               136                    1
# 25                            4               576                    8
# 26                            5              1017                    1
# 27                            2               175                    9
# 29                            1                30                    2
# 30                            2               175                    2
# 31                            3               465                    2
# 33                            4               750                    2
# 37                            3               283                    1
# 39                            4               672                    6
# 40                            4               750                    1
# 41                            4               600                    6
# ...                         ...               ...                  ...
# 153783                        7              5500                    6
# 153784                        6              1666                    1
# 153785                        7              5666                    1
# 153786                        7             11000                    6
# 153787                        6              1632                    6
# 153789                        6              1650                    6
# 153790                        7              5000                    1
# 153791                        7              5000                    6
# 153792                        7              3000                    1
# 153794                        4               750                    1
# 153795                        7              2800                    6
# 153796                        5              1225                    1
# 153797                        7              4000                    6
# 153798                        7              6000                    6
# 153799                        6              1650                    6
# 153801                        7              6500                    1
# 153802                        7              4500                    6
# 153808                        7              8000                    6
# 153810                        6              1510                    2
# 153811                        7              3370                    1
# 153815                        7              7760                    6
# 153817                        7              2400                    1
# 153818                        7              4700                    6
# 153819                        7              4775                    1
# 153823                        7              3242                    1
# 153830                        6              2000                    6
# 153832                        7              2500                    6
# 153834                        7              8333                    1
# 153835                        7              7166                    1
# 153836                        7              2500                    1
#
#         Unidade Federal Segurança alimentar        Regiao
# 2                    11                 não         Norte
# 3                    11                 sim         Norte
# 4                    11                 sim         Norte
# 6                    11                 sim         Norte
# 7                    11                 sim         Norte
# 8                    11                 não         Norte
# 9                    11                 sim         Norte
# 10                   11                 não         Norte
# 12                   11                 sim         Norte
# 13                   11                 sim         Norte
# 14                   11                 sim         Norte
# 15                   11                 sim         Norte
# 16                   11                 sim         Norte
# 18                   11                 sim         Norte
# 19                   11                 não         Norte
# 21                   11                 sim         Norte
# 22                   11                 sim         Norte
# 23                   11                 sim         Norte
# 24                   11                 sim         Norte
# 25                   11                 não         Norte
# 26                   11                 sim         Norte
# 27                   11                 não         Norte
# 29                   11                 sim         Norte
# 30                   11                 sim         Norte
# 31                   11                 sim         Norte
# 33                   11                 sim         Norte
# 37                   11                 sim         Norte
# 39                   11                 sim         Norte
# 40                   11                 sim         Norte
# 41                   11                 sim         Norte
# ...                 ...                 ...           ...
# 153783               53                 sim  Centro-Oeste
# 153784               53                 sim  Centro-Oeste
# 153785               53                 sim  Centro-Oeste
# 153786               53                 sim  Centro-Oeste
# 153787               53                 sim  Centro-Oeste
# 153789               53                 sim  Centro-Oeste
# 153790               53                 sim  Centro-Oeste
# 153791               53                 sim  Centro-Oeste
# 153792               53                 sim  Centro-Oeste
# 153794               53                 sim  Centro-Oeste
# 153795               53                 sim  Centro-Oeste
# 153796               53                 sim  Centro-Oeste
# 153797               53                 sim  Centro-Oeste
# 153798               53                 sim  Centro-Oeste
# 153799               53                 sim  Centro-Oeste
# 153801               53                 sim  Centro-Oeste
# 153802               53                 sim  Centro-Oeste
# 153808               53                 sim  Centro-Oeste
# 153810               53                 sim  Centro-Oeste
# 153811               53                 sim  Centro-Oeste
# 153815               53                 sim  Centro-Oeste
# 153817               53                 sim  Centro-Oeste
# 153818               53                 sim  Centro-Oeste
# 153819               53                 sim  Centro-Oeste
# 153823               53                 sim  Centro-Oeste
# 153830               53                 sim  Centro-Oeste
# 153832               53                 sim  Centro-Oeste
# 153834               53                 sim  Centro-Oeste
# 153835               53                 sim  Centro-Oeste
# 153836               53                 sim  Centro-Oeste
#
# [117775 rows x 6 columns]

# %%
RegNorte = NewData[(NewData['Regiao'] == 'Norte' )]
RegSul = NewData[(NewData['Regiao'] == 'Sul' )]
RegCentroOeste = NewData[(NewData['Regiao'] == 'Centro-Oeste' )]
RegNordeste = NewData[(NewData['Regiao'] == 'Nordeste' )]
RegSudeste = NewData[(NewData['Regiao'] == 'Sudeste' )]

# %%
faixa = range(0,6000,100)

fig = plt.figure(figsize=(10,12))

plt.subplot(231)
plot = RegNorte['Rendimento valor'].plot.hist(bins=faixa,title='HISTOGRAMA', normed=1, figsize=(6, 6), alpha=0.5)
plt.ylabel('Frequência absoluta')
plt.xlabel('renda (em reais)')

plt.subplot(232)
plot = RegNordeste['Rendimento valor'].plot.hist(bins=faixa,title='HISTOGRAMA', normed=1, figsize=(6, 6), alpha=0.5)
plt.ylabel('Frequência absoluta')
plt.xlabel('renda (em reais)')

plt.subplot(233)
plot = RegSul['Rendimento valor'].plot.hist(bins=faixa,title='HISTOGRAMA', normed=1, figsize=(6, 6), alpha=0.5)
plt.ylabel('Frequência absoluta')
plt.xlabel('renda (em reais)')

plt.subplot(234)
plot = RegSudeste['Rendimento valor'].plot.hist(bins=faixa,title='HISTOGRAMA', normed=1, figsize=(6, 6), alpha=0.5)
plt.ylabel('Frequência absoluta')
plt.xlabel('renda (em reais)')

plt.subplot(235)
plot = RegCentroOeste['Rendimento valor'].plot.hist(bins=faixa,title='HISTOGRAMA', normed=1, figsize=(6, 6), alpha=0.5)
plt.ylabel('Frequência absoluta')
plt.xlabel('renda (em reais)')
plt.tight_layout()
plt.show()

# %%
NewData['fim do estoque mensal'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\Julian\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2392             try:
# -> 2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5239)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5085)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20405)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20359)()
#
# KeyError: 'fim do estoque mensal'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-e44ed29bc2d3> in <module>()
# ----> 1 NewData['fim do estoque mensal'].value_counts()
#
# C:\Users\Julian\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2060             return self._getitem_multilevel(key)
#    2061         else:
# -> 2062             return self._getitem_column(key)
#    2063
#    2064     def _getitem_column(self, key):
#
# C:\Users\Julian\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2067         # get column
#    2068         if self.columns.is_unique:
# -> 2069             return self._get_item_cache(key)
#    2070
#    2071         # duplicate columns & possible reduce dimensionality
#
# C:\Users\Julian\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1532         res = cache.get(item)
#    1533         if res is None:
# -> 1534             values = self._data.get(item)
#    1535             res = self._box_item_values(item, values)
#    1536             cache[item] = res
#
# C:\Users\Julian\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# C:\Users\Julian\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
# -> 2395                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2396
#    2397         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5239)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5085)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20405)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20359)()
#
# KeyError: 'fim do estoque mensal'

# %% [markdown]
# Descreva aqui suas conclusões!

# %%
ct = pd.crosstab(NewData['Regiao'], NewData['Segurança alimentar'])

# %%
ct.plot(kind='bar', color=('blue', 'red'), legend=True)
plt.ylabel('Número de domicilios')
plt.xlabel('Região')
plt.title('Número de domicilios com segurança alimentar por regiões brasileiras')

# %%
ct2 = pd.crosstab(NewData['Regiao'], NewData['Segurança alimentar'], normalize= 'index')
ct2 = ct2.round(4)*100
ct2

# %%
ct2.plot(kind='bar', color=('blue', 'red'), legend=True)
plt.ylabel('Percentual de domicilios')
plt.xlabel('Região')
plt.title('Percentual de domicilios com segurança alimentar por regiões brasileiras')

# %% [markdown]
# ___
# ## Conclusão
